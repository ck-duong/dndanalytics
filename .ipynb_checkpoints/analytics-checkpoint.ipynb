# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %%
all_fp = os.path.join('data', 'dnd_chars_all.tsv')
alldf = pd.read_csv(all_fp, sep='\t')
alldf = alldf.drop(columns = ['name', 'ip', 'finger', 'hash'])
alldf.head()
# Out:
#        race background                  date      class justClass  subclass  \
# 0  Wood Elf     Custom  2019-04-04T20:58:17Z   Ranger 1    Ranger       NaN
# 1  Tiefling   Courtier  2019-04-04T17:47:10Z    Rogue 3     Rogue  Assassin
# 2  High Elf       Sage  2019-04-04T17:21:11Z   Wizard 1    Wizard       NaN
# 3     Human     Urchin  2019-04-04T05:49:56Z  Fighter 1   Fighter       NaN
# 4     Human     Urchin  2019-04-04T04:48:19Z  Fighter 2   Fighter       NaN
#
#    level         feats  HP  AC  ...        country  countryCode  \
# 0      1           NaN  11  13  ...         Canada           CA
# 1      3           NaN  21  13  ...         Canada           CA
# 2      1           NaN   8  16  ...  United States           US
# 3      1  Sharpshooter  12  15  ...         Canada           CA
# 4      2  Sharpshooter  18  15  ...         Canada           CA
#
#    processedAlignment  good  lawful  processedRace  \
# 0                 NaN   NaN     NaN            Elf
# 1                 NaN   NaN     NaN       Tiefling
# 2                  NN   NaN     NaN            Elf
# 3                  LN   NaN     NaN          Human
# 4                  LN   NaN     NaN          Human
#
#                                      processedSpells  \
# 0                                                NaN
# 1                                                NaN
# 2  Toll the Dead*0|Prestidigitation*0|Fire Bolt*0...
# 3                                                NaN
# 4                                                NaN
#
#              processedWeapons levelGroup                alias
# 0          Shortsword|Longbow        1-3     wizardly_dewdney
# 1      Rapier|Shortbow|Dagger        1-3  optimistic_herschel
# 2                Quarterstaff        1-3     blissful_murdock
# 3  Shortsword|Crossbow, Heavy        1-3    inspiring_swirles
# 4  Shortsword|Crossbow, Heavy        1-3    inspiring_swirles
#
# [5 rows x 32 columns]

# %%
alldf.columns
# Out:
# Index(['race', 'background', 'date', 'class', 'justClass', 'subclass', 'level',
#        'feats', 'HP', 'AC', 'Str', 'Dex', 'Con', 'Int', 'Wis', 'Cha',
#        'alignment', 'skills', 'weapons', 'spells', 'day', 'castingStat',
#        'country', 'countryCode', 'processedAlignment', 'good', 'lawful',
#        'processedRace', 'processedSpells', 'processedWeapons', 'levelGroup',
#        'alias'],
#       dtype='object')

# %%
def clean_titles(word):
    if not pd.isna(word):
        listed = word.replace('-', ' ').split()
        cleaned = ' '.join(listed)
        cleaned = cleaned.title()
        return cleaned
    else:
        return word

# %%
def clean_spells(word):
    if not pd.isna(word):
        spellbook = {}
        listed = word.split('|')
        
        for spell in listed:
            level = spell[-1]
            if level in spellbook.keys():
                spellbook[level].append(spell[:-2])
            else:
                spellbook[level] = [spell[:-2]]
                
        return spellbook
    return np.nan

# %%
def clean_misc(col):
    def clean(word):
        if not pd.isna(word):
            return word.split('|')
        return np.nan
    return col.apply(clean)

# %%
alldf['race'] = alldf['race'].apply(clean_titles)
alldf['background'] = alldf['background'].apply(clean_titles)
alldf['processedSpells'] = alldf['processedSpells'].apply(clean_spells)
alldf[['class', 'justClass', 'subclass', 'feats', 'skills', 'processedWeapons']] = \
alldf[['class', 'justClass', 'subclass', 'feats', 'skills', 'processedWeapons']].apply(clean_misc)

# %%
alldf.head()
# Out:
#        race background                  date        class  justClass  \
# 0  Wood Elf     Custom  2019-04-04T20:58:17Z   [Ranger 1]   [Ranger]
# 1  Tiefling   Courtier  2019-04-04T17:47:10Z    [Rogue 3]    [Rogue]
# 2  High Elf       Sage  2019-04-04T17:21:11Z   [Wizard 1]   [Wizard]
# 3     Human     Urchin  2019-04-04T05:49:56Z  [Fighter 1]  [Fighter]
# 4     Human     Urchin  2019-04-04T04:48:19Z  [Fighter 2]  [Fighter]
#
#      subclass  level           feats  HP  AC  ...        country  countryCode  \
# 0         NaN      1             NaN  11  13  ...         Canada           CA
# 1  [Assassin]      3             NaN  21  13  ...         Canada           CA
# 2         NaN      1             NaN   8  16  ...  United States           US
# 3         NaN      1  [Sharpshooter]  12  15  ...         Canada           CA
# 4         NaN      2  [Sharpshooter]  18  15  ...         Canada           CA
#
#    processedAlignment  good  lawful  processedRace  \
# 0                 NaN   NaN     NaN            Elf
# 1                 NaN   NaN     NaN       Tiefling
# 2                  NN   NaN     NaN            Elf
# 3                  LN   NaN     NaN          Human
# 4                  LN   NaN     NaN          Human
#
#                                      processedSpells  \
# 0                                                NaN
# 1                                                NaN
# 2  {'0': ['Toll the Dead', 'Prestidigitation', 'F...
# 3                                                NaN
# 4                                                NaN
#
#                 processedWeapons levelGroup                alias
# 0          [Shortsword, Longbow]        1-3     wizardly_dewdney
# 1     [Rapier, Shortbow, Dagger]        1-3  optimistic_herschel
# 2                 [Quarterstaff]        1-3     blissful_murdock
# 3  [Shortsword, Crossbow, Heavy]        1-3    inspiring_swirles
# 4  [Shortsword, Crossbow, Heavy]        1-3    inspiring_swirles
#
# [5 rows x 32 columns]

# %%
tester = alldf['processedSpells'][2].split('|')
display(tester)
spellbook = {}
for spell in tester:
    level = spell[-1]
    if level in spellbook.keys():
        spellbook[level].append(spell[:-2])
    else:
        spellbook[level] = [spell[:-2]]
# Out:
# ['Toll the Dead*0',
#  'Prestidigitation*0',
#  'Fire Bolt*0',
#  'Mage Hand*0',
#  'Absorb Elements*1',
#  'Shield*1',
#  'Magic Missile*1',
#  'Chromatic Orb*1',
#  'Find Familiar*1']
# {'0': ['Toll the Dead', 'Prestidigitation', 'Fire Bolt', 'Mage Hand'],
#  '1': ['Absorb Elements',
#   'Shield',
#   'Magic Missile',
#   'Chromatic Orb',
#   'Find Familiar']}
